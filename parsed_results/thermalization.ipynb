# %%
from utils import *
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json

# %%
experiments_pairs = [
    (Experiment.basic_zero_plus_discr, Experiment.basic_zero_plus_discr_therm),
    (Experiment.reset, Experiment.reset_therm)
]

# %%
method = "bellman"
 
def get_algorithms(experiment, method):
    p1 = get_experiment_path(experiment)
    c1 = get_algorithms_count(experiment, method=method)
    
    exp_path = get_experiment_path(experiment)
    result = []
    for i in range(c1):
        alg_path = os.path.join(exp_path, "raw_algorithms", "A_"+str(i).txt)
        f = open(alg_path)
        s = f.read()
        f.close()
        result.append(s)
        
    return result
        
        
    
for (exp1, exp2) in experiments_pairs:
    algorithms1 = get_algorithms(exp1, method)
    algorithms2 = get_algorithms(exp2, method)
    if len(algorithms)
