# %%
from utils import *
import pandas as pd
import seaborn as sns

# %%
for experiment in Experiment:
    print_stats_summary(experiment)
# Out:
# ------ Experiment.basic_zero_plus_discr ------
# count hardware:  55
# count embeddings:  109
# total diff. algorithms:  82
# accuracy perfect hardware: 0.75
# min. accuracy: 0.52602
# max. accuracy: 0.75
#
# num. algorithms per horizon
# 3 :  82
# ---------------
#
#
# ------ Experiment.bell_state_reach ------
# count hardware:  45
# count embeddings:  140
# total diff. algorithms:  60
# accuracy perfect hardware: 0.5, 1.0, 0.5, 1.0, 1.0
# min. accuracy: 0.49975
# max. accuracy: 1.00501
#
# num. algorithms per horizon
# 1 :  7
# 2 :  49
# 3 :  4
# ---------------
#
#
# ------ Experiment.bitflip_cxh ------
# count hardware:  45
# count embeddings:  203
# total diff. algorithms:  14
# accuracy perfect hardware: 0.5
# min. accuracy: 0.5
# max. accuracy: 0.50907
#
# num. algorithms per horizon
# 6 :  14
# ---------------
#
#
# ------ Experiment.bitflip_ipma ------
# count hardware:  45
# count embeddings:  141
# total diff. algorithms:  28
# ...

# %%
for experiment in Experiment:
    print("-----", experiment.value, "-------")
    data = pd.read_csv(get_stats_path(Experiment.basic_zero_plus_discr))
    data
    print(data.describe())
    print("----------------------")
# Out:
# ----- basic_zero_plus_discr -------
#        embedding_index  horizon  pomdp_build_time  probability  method_time  \
# count       109.000000    109.0        109.000000   109.000000   109.000000
# mean          0.495413      3.0          0.015509     0.716562    14.082569
# std           0.502288      0.0          0.011921     0.054448     1.934714
# min           0.000000      3.0          0.002730     0.526020     6.000000
# 25%           0.000000      3.0          0.009160     0.717730    13.000000
# 50%           0.000000      3.0          0.010690     0.743450    14.000000
# 75%           1.000000      3.0          0.015800     0.747150    15.000000
# max           1.000000      3.0          0.054340     0.750000    18.000000
#
#        algorithm_index
# count       109.000000
# mean         34.293578
# std          24.474591
# min           0.000000
# 25%          13.000000
# 50%          30.000000
# 75%          55.000000
# max          81.000000
# ----------------------
# ...

# %%
# Out:
#        embedding_index  horizon  pomdp_build_time  probability  method_time  \
# count       109.000000    109.0        109.000000   109.000000   109.000000
# mean          0.495413      3.0          0.015509     0.716562    14.082569
# std           0.502288      0.0          0.011921     0.054448     1.934714
# min           0.000000      3.0          0.002730     0.526020     6.000000
# 25%           0.000000      3.0          0.009160     0.717730    13.000000
# 50%           0.000000      3.0          0.010690     0.743450    14.000000
# 75%           1.000000      3.0          0.015800     0.747150    15.000000
# max           1.000000      3.0          0.054340     0.750000    18.000000
#
#        algorithm_index
# count       109.000000
# mean         34.293578
# std          24.474591
# min           0.000000
# 25%          13.000000
# 50%          30.000000
# 75%          55.000000
# max          81.000000
